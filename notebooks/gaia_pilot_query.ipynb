# %%
import pyvo

tap = pyvo.dal.TAPService(
    "https://gea.esac.esa.int/tap-server/tap"
)

query = """
SELECT TOP 100
    source_id,
    ra, dec,
    parallax, parallax_error,
    pmra, pmra_error,
    pmdec, pmdec_error,
    phot_g_mean_mag,
    phot_bp_mean_mag,
    phot_rp_mean_mag,
    ruwe,
    astrometric_params_solved,
    radial_velocity,
    radial_velocity_error
FROM gaiadr3.gaia_source
WHERE 1 = CONTAINS(
    POINT('ICRS', ra, dec),
    CIRCLE('ICRS', 308.3, 41.2, 5.0)
)
AND parallax BETWEEN 0.35 AND 1.10
AND phot_g_mean_mag < 19
"""

result = tap.search(query)
table = result.to_table()

print(len(table))
print(table.colnames)
# Out:
# 100
# ['source_id', 'ra', 'dec', 'parallax', 'parallax_error', 'pmra', 'pmra_error', 'pmdec', 'pmdec_error', 'phot_g_mean_mag', 'phot_bp_mean_mag', 'phot_rp_mean_mag', 'ruwe', 'astrometric_params_solved', 'radial_velocity', 'radial_velocity_error']

# %%
table
# Out:
# <Table length=100>
#      source_id              ra         ... radial_velocity radial_velocity_error
#                            deg         ...      km / s             km / s
#        int64             float64       ...     float32            float32
# ------------------- ------------------ ... --------------- ---------------------
# 2065932118954911488 314.17371112595896 ...              --                    --
# 2062355437695111680  304.1270855907514 ...              --                    --
# 2066285779441290624  311.7162284002705 ...              --                    --
# 2081508689730307200  303.8920735846311 ...              --                    --
# 2065996715263410176 313.41520620818585 ...              --                    --
# 2069939800178064768 308.99907885486056 ...              --                    --
# 1872706728638892800   313.094067930652 ...              --                    --
# 1872637352019844480 314.10393174186834 ...              --                    --
# 2065996607884122880  313.5164319886579 ...              --                    --
#                 ...                ... ...             ...                   ...
# 2074911040154053504  302.1417166300998 ...              --                    --
# 2061462428090204288 304.97449520829804 ...              --                    --
# 2071128788862983808  309.3941747658222 ...              --                    --
# 2070994133060981888 307.78469741049133 ...              --                    --
# 2065943045352445696  313.6455160179525 ...              --                    --
# 2062509815994524544  303.7378186739611 ...              --                    --
# 2063244672022576128 310.78132379075015 ...              --                    --
# 2071163938885873792 308.64011897439855 ...              --                    --
# 1872735723951624320 312.78135552814064 ...              --                    --
